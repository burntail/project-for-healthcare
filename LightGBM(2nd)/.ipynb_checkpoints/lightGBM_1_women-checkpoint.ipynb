# %%
import numpy as np
import pandas as pd
A_a_1=pd.read_csv("[Nut2NHI] data_hw_ver4.csv")
A_a_1_cols=A_a_1.columns

A_a_1_cols_new=['sex','age','ID','year']


for x in A_a_1_cols:
    if x.startswith("HE"):
        A_a_1_cols_new.append(x)
       
A_a_1=A_a_1[A_a_1_cols_new]

test=pd.read_excel("검진데이터 정리본_유니스트_송부.xlsx")

test=test.drop(['성명','환자번호','r-GTP','알부민','BUN'],axis=1)

test['생년월일']=test['생년월일'].apply(lambda x: int(str(x)[0:2])+1900)
test['age']=test['생년월일'].apply(lambda x: 2019-x+1)
#test
test=test.drop(['검진일','생년월일'],axis=1)

test.columns=['sex','HE_ht','HE_wt','HE_BMI','HE_sbp','HE_dbp','HE_wc','HE_HbA1c','HE_ast','HE_alt','HE_chol','HE_HDL_st2','HE_LDL_drct','HE_TG','HE_glu','HE_crea','HE_Upro','age']
A_a_1=A_a_1[['sex','HE_ht','HE_wt','HE_BMI','HE_sbp','HE_dbp','HE_wc','HE_HbA1c','HE_ast','HE_alt','HE_chol','HE_HDL_st2','HE_LDL_drct','HE_TG','HE_glu','HE_crea','HE_Upro','age']]

# %%
A_a_1=A_a_1[(A_a_1['HE_ht'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_wt'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_wc'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_BMI'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_sbp'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_dbp'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_Upro'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_HbA1c'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_glu'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_chol'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_TG'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_HDL_st2'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_LDL_drct'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_crea'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_ast'].notnull())]
A_a_1=A_a_1[(A_a_1['HE_alt'].notnull())]

A_a_1=A_a_1[A_a_1['age']>=20]


test=test[(test['HE_ht'].notnull())]
test=test[(test['HE_wt'].notnull())]
test=test[(test['HE_wc'].notnull())]
test=test[(test['HE_BMI'].notnull())]
test=test[(test['HE_sbp'].notnull())]
test=test[(test['HE_dbp'].notnull())]
test=test[(test['HE_Upro'].notnull())]
test=test[(test['HE_HbA1c'].notnull())]
test=test[(test['HE_glu'].notnull())]
test=test[(test['HE_chol'].notnull())]
test=test[(test['HE_TG'].notnull())]
test=test[(test['HE_HDL_st2'].notnull())]
test=test[(test['HE_LDL_drct'].notnull())]
test=test[(test['HE_crea'].notnull())]
test=test[(test['HE_ast'].notnull())]
test=test[(test['HE_alt'].notnull())]

# test=test[test['age']>=20]

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 534
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          491 non-null    object
#  1   HE_ht        491 non-null    float64
#  2   HE_wt        491 non-null    float64
#  3   HE_BMI       491 non-null    float64
#  4   HE_sbp       491 non-null    float64
#  5   HE_dbp       491 non-null    float64
#  6   HE_wc        491 non-null    float64
#  7   HE_HbA1c     491 non-null    float64
#  8   HE_ast       491 non-null    int64
#  9   HE_alt       491 non-null    int64
#  10  HE_chol      491 non-null    int64
#  11  HE_HDL_st2   491 non-null    float64
#  12  HE_LDL_drct  491 non-null    float64
#  13  HE_TG        491 non-null    int64
#  14  HE_glu       491 non-null    int64
#  15  HE_crea      491 non-null    float64
#  16  HE_Upro      491 non-null    float64
#  17  age          491 non-null    int64
# ...

# %%
import lightgbm 
from lightgbm import LGBMRegressor
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score ,mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt


dataset_total=A_a_1
dataset_men=A_a_1[A_a_1['sex']==1]
dataset_women=A_a_1[A_a_1['sex']==2]



target_total=dataset_total["age"]
features_total=dataset_total.drop(["age"],axis=1)

target_men=dataset_men["age"]
features_men=dataset_men.drop(["sex","age"],axis=1)

target_women=dataset_women["age"]
features_women=dataset_women.drop(["sex","age"],axis=1)

# %%
test_men=test[(test['sex']=='남')|(test['sex']=='남자')]
test_women=test[(test['sex']=='여')|(test['sex']=='여자')]

test_men_target=test_men['age']
test_men_features=test_men.drop(['sex','age'],axis=1)

test_women_target=test_women['age']
test_women_features=test_women.drop(['sex','age'],axis=1)

# %%
plt.rcParams["figure.figsize"] = (5, 5)

from sklearn.preprocessing import MinMaxScaler
# men_x_train, men_x_test, men_y_train, men_y_test= train_test_split(features_men,target_men,test_size=0.3,random_state=200)


sc=MinMaxScaler()

lgb_reg_2 = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=3,num_leaves=32,n_estimators=300) 

features_women_std=sc.fit_transform(features_women)

features_women=pd.DataFrame(features_women_std,columns=['HE_ht','HE_wt','HE_BMI','HE_sbp','HE_dbp','HE_wc','HE_HbA1c','HE_ast','HE_alt','HE_chol','HE_HDL_st2','HE_LDL_drct','HE_TG','HE_glu','HE_crea','HE_Upro'])

lgb_reg_2.fit(features_women, target_women)



test_women_features_std=sc.transform(test_women_features)
test_women_features=pd.DataFrame(test_women_features_std,columns=['HE_ht','HE_wt','HE_BMI','HE_sbp','HE_dbp','HE_wc','HE_HbA1c','HE_ast','HE_alt','HE_chol','HE_HDL_st2','HE_LDL_drct','HE_TG','HE_glu','HE_crea','HE_Upro'])


answer = pd.DataFrame(test_women_target.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_2.predict(test_women_features))
plt.title("women case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.058982
# [LightGBM] [Debug] init for col-wise cost 0.000014 seconds, init for row-wise cost 0.001102 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2385
# [LightGBM] [Info] Number of data points in the train set: 4619, number of used features: 16
# [LightGBM] [Info] Start training from score 52.230569
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# ...

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_2, ax=ax)
plt.xlabel("LgihtGBM Feature of women Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of women Importance')

# %%
import shap

shap_values = shap.TreeExplainer(lgb_reg_2).shap_values(test_men_features)
shap.summary_plot(shap_values, test_women_features, plot_type="bar")

# %%
test_women_features.loc[:,'age']=test_women_target



#test_women_features=test_women_features[(test_women_features['age']>=60)]

women_y_test=test_women_features.iloc[:,[16]]
women_x_test=test_women_features.drop(["age"],axis=1)


# men_x_test

# %%
#body age

women_x_train_body=features_women.loc[:,["HE_ht","HE_wt","HE_wc","HE_BMI"]]

women_x_test_body=test_women_features.loc[:,["HE_ht","HE_wt","HE_wc","HE_BMI"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_body = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_body.fit(women_x_train_body, target_women)

answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_body.predict(women_x_test_body)) 
plt.title("body age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000216
# [LightGBM] [Debug] init for col-wise cost 0.000068 seconds, init for row-wise cost 0.000872 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000997 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 4619, number of used features: 4
# [LightGBM] [Info] Start training from score 52.230569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 167 and depth = 10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_body, ax=ax)
plt.xlabel("LgihtGBM Feature of body age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of body age Importance')

# %%
#metabolism

# total_x_train

women_x_train_meta=features_women.loc[:,["HE_wc","HE_sbp","HE_dbp","HE_HDL_st2","HE_LDL_drct","HE_TG","HE_glu"]] 

women_x_test_meta=test_women_features.loc[:,["HE_wc","HE_sbp","HE_dbp","HE_HDL_st2","HE_LDL_drct","HE_TG","HE_glu"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_meta = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_meta.fit(women_x_train_meta, target_women)



answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_meta.predict(women_x_test_meta)) 
plt.title("metabolism age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000210
# [LightGBM] [Debug] init for col-wise cost 0.000008 seconds, init for row-wise cost 0.000894 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1148
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 7
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 152 and depth = 10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_meta, ax=ax) #여기 수정
plt.xlabel("LgihtGBM Feature of metabolism age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of metabolism age Importance')

# %%
# blood vessel age

women_x_train_blood=features_women.loc[:,["HE_wc","HE_sbp","HE_dbp","HE_HDL_st2","HE_LDL_drct","HE_TG","HE_glu"]] 

women_x_test_blood=test_women_features.loc[:,["HE_wc","HE_sbp","HE_dbp","HE_HDL_st2","HE_LDL_drct","HE_TG","HE_glu"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_blood = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_blood.fit(women_x_train_blood, target_women)



answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_blood.predict(women_x_test_blood)) 
plt.title("blood vessel age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000210
# [LightGBM] [Debug] init for col-wise cost 0.000023 seconds, init for row-wise cost 0.017978 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.018125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1148
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 7
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 152 and depth = 10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))

plot_importance(lgb_reg_blood, ax=ax) #여기수정
plt.xlabel("LgihtGBM Feature of blood age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of blood age Importance')

# %%
# immunity age

women_x_train_immu=features_women.loc[:,["HE_HbA1c","HE_ast","HE_alt","HE_HDL_st2"]] 

women_x_test_immu=test_women_features.loc[:,["HE_HbA1c","HE_ast","HE_alt","HE_HDL_st2"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_immu = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_immu.fit(women_x_train_immu, target_women)



answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_immu.predict(women_x_test_immu)) 
plt.title("immunity age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000263
# [LightGBM] [Debug] init for col-wise cost 0.000013 seconds, init for row-wise cost 0.002518 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 409
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 4
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_immu, ax=ax) #여기 수정
plt.xlabel("LgihtGBM Feature of immunity age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of immunity age Importance')

# %%
#lung age

women_x_train_lung=features_women.loc[:,["HE_sbp","HE_dbp"]]
women_x_test_lung=test_women_features.loc[:,["HE_sbp","HE_dbp"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_lung = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_lung.fit(women_x_train_lung, target_women)


answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_lung.predict(women_x_test_lung))
plt.title("lung age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000210
# [LightGBM] [Debug] init for col-wise cost 0.000009 seconds, init for row-wise cost 0.000984 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004606 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 164
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 2
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_lung, ax=ax)
plt.xlabel("LgihtGBM Feature of immunity age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of immunity age Importance')

# %%
#kidney age

women_x_train_kid=features_women.loc[:,["HE_crea"]]
women_x_test_kid=test_women_features.loc[:,["HE_crea"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_kid = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_kid.fit(women_x_train_kid, target_women)


answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_kid.predict(women_x_test_kid))
plt.title("kidney age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000210
# [LightGBM] [Debug] init for col-wise cost 0.000007 seconds, init for row-wise cost 0.000918 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000971 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 104
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 1
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 55 and depth = 10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_kid, ax=ax)
plt.xlabel("LgihtGBM Feature of kidney age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of kidney age Importance')

# %%
#joint age

women_x_train_jo=features_women.loc[:,["HE_ht","HE_wt","HE_BMI"]]
women_x_test_jo=test_women_features.loc[:,["HE_ht","HE_wt","HE_BMI"]]

# %%
plt.rcParams["figure.figsize"] = (5, 5)

lgb_reg_jo = LGBMRegressor(verbosity=50,learning_rate=0.05,boosting='gbdt',metric='regression_l2',max_depth=10,num_leaves=65536,n_estimators=100) 
lgb_reg_jo.fit(women_x_train_jo, target_women)


answer = pd.DataFrame(women_y_test.reset_index())
del answer["index"]

plt.scatter(answer,lgb_reg_jo.predict(women_x_test_jo))
plt.title("joint age case")
plt.xlabel("age")
plt.ylabel("predict")
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000210
# [LightGBM] [Debug] init for col-wise cost 0.000007 seconds, init for row-wise cost 0.000642 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000734 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 765
# [LightGBM] [Info] Number of data points in the train set: 4757, number of used features: 3
# [LightGBM] [Info] Start training from score 50.174900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 140 and depth = 10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgb_reg_jo, ax=ax)
plt.xlabel("LgihtGBM Feature of joint age Importance")
# Out:
# Text(0.5, 0, 'LgihtGBM Feature of joint age Importance')
